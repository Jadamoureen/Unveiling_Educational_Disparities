# %% [markdown]
# # Visualizing Female School Dropout Rates: Unveiling Educational Disparities
#
# The increasing number of women facing disadvantageous circumstances in society has reached alarming proportions. Among the contributing factors, one prominent issue is the high dropout rate of girls from school.
# In this project, our goal is to comprehend the specific educational levels at which girls are most likely to drop out. This investigation is part of a broader mission to understand the underlying reasons for this phenomenon and offer effective strategies to address this problem.Utilizing the comprehensive dataset provided by UNICEF, we will employ various visualization techniques, including dynamic charts, to gain a deeper understanding of the issue at hand. By analyzing statistics and data, we can paint a clear picture that will guide us towards sustainable solutions to empower women and prevent further dropout rates.Our primary focus is to capture and analyze the number of school dropouts at different educational levels. By delving deeper into the data, we aim to identify the root causes behind these dropouts. Through detailed exploration, we can shed light on the challenges that hinder girls' educational progress and develop effective strategies to mitigate these obstacles.
# Armed with the insights garnered from our analysis, we will work towards providing actionable recommendations. These solutions will be designed to address the underlying causes of female school dropout, enabling us to assist women in reaching their educational milestones and fulfilling their potential.
#
# By unraveling the complexities of this issue and leveraging data-driven visualizations, we strive to create a transformative impact. Our ultimate goal is to break the cycle of educational disadvantage for girls and foster an environment that empowers women to thrive at every level of education.

# %%
# importing the libraries 

import pandas as pd 

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset 

school_data = pd.read_csv("School-completion-rates-Nov2019.csv")
school_data
# Out:
#     Unnamed: 0 Indicator name: Completion rate,  primary Unnamed: 2  \
# 0          NaN                                       NaN        NaN
# 1     ISO_Code                                   Country     Region
# 2          AFG                               Afghanistan         SA
# 3          ALB                                   Albania        ECA
# 4          DZA                                   Algeria       MENA
# ..         ...                                       ...        ...
# 222        NaN         African sub-region - North Africa        NaN
# 223        NaN         African sub-region - South Africa        NaN
# 224        NaN          African sub-region - West Africa        NaN
# 225        NaN                       Africa region - All        NaN
# 226        NaN                                     World        NaN
#
#      Unnamed: 3                       Unnamed: 4          Unnamed: 5  \
# 0           NaN                              NaN                 NaN
# 1    Sub-region  Least developed countries (LDC)  Africa sub-regions
# 2           NaN                              LDC                 NaN
# 3          EECA                              NaN                 NaN
# 4           NaN                              NaN     Northern Africa
# ..          ...                              ...                 ...
# 222         NaN                              NaN     Northern Africa
# 223         NaN                              NaN     Southern Africa
# 224         NaN                              NaN      Western Africa
# 225         NaN                              NaN                 NaN
# 226         NaN                              NaN                 NaN
#
#         Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 15  \
# 0              NaN      Total     Gender        NaN  ...         NaN
# 1    Africa region      Total       Male     Female  ...      Fourth
# 2              NaN        54         67         40   ...         60
# 3              NaN        92         91         93   ...         92
# 4              All        94         93         94   ...         96
# ..             ...        ...        ...        ...  ...         ...
# 222            NaN        91         NaN        NaN  ...         NaN
# 223            NaN        67         NaN        NaN  ...         NaN
# 224            NaN        65         NaN        NaN  ...         NaN
# 225            All        66         NaN        NaN  ...         NaN
# 226            NaN        82         NaN        NaN  ...         NaN
#
#     Unnamed: 16     Unnamed: 17                                  Unnamed: 18  \
# 0           NaN             NaN                                          NaN
# 1       Richest          Source   Total Population, one year before primary
# 2           75       DHS 2015                                     6,170,913
# 3           98     DHS 2017-18                                      156,833
# 4           99    MICS 2012-13                                    4,040,275
# ..          ...             ...                                          ...
# 222         NaN             NaN                                          NaN
# 223         NaN             NaN                                          NaN
# 224         NaN             NaN                                          NaN
# 225         NaN             NaN                                          NaN
# 226         NaN             NaN                                          NaN
#
#     Unnamed: 19 Unnamed: 20   Unnamed: 21   Unnamed: 22 Unnamed: 23  \
# 0           NaN         NaN           NaN           NaN         NaN
# 1           NaN         NaN           NaN           NaN         NaN
# 2     3160379.0   3010534.0  1.606042e+06  4.564871e+06      26.026
# 3       81809.0     75024.0  9.741211e+04  5.942089e+04      62.112
# 4     2060745.0   1979530.0  2.979016e+06  1.061259e+06      73.733
# ..          ...         ...           ...           ...         ...
# 222         NaN         NaN           NaN           NaN         NaN
# 223         NaN         NaN           NaN           NaN         NaN
# 224         NaN         NaN           NaN           NaN         NaN
# 225         NaN         NaN           NaN           NaN         NaN
# 226         NaN         NaN           NaN           NaN         NaN
#
#      Unnamed: 24
# 0            NaN
# 1            NaN
# 2         73.974
# 3         37.888
# 4         26.267
# ..           ...
# 222          NaN
# 223          NaN
# 224          NaN
# 225          NaN
# 226          NaN
#
# [227 rows x 25 columns]

# %% [markdown]
# #### displaying the dataset notice they are two rows the unamed row and the NaN row

# %%
#set the first (notna/ unnamed) row as header

school_data.columns = school_data.iloc[0]

# %%
#emove that unamed row from the dataset 

school_data = school_data.iloc[1:,].reindex()

# %%
school_data.head()
# Out:
# 0       NaN          NaN     NaN         NaN                              NaN  \
# 1  ISO_Code      Country  Region  Sub-region  Least developed countries (LDC)
# 2       AFG  Afghanistan      SA         NaN                              LDC
# 3       ALB      Albania     ECA        EECA                              NaN
# 4       DZA      Algeria    MENA         NaN                              NaN
# 5       AND      Andorra     ECA          WE                              NaN
#
# 0                 NaN            NaN  Total Gender     NaN  ...     NaN  \
# 1  Africa sub-regions  Africa region  Total   Male  Female  ...  Fourth
# 2                 NaN            NaN    54     67      40   ...     60
# 3                 NaN            NaN    92     91      93   ...     92
# 4     Northern Africa            All    94     93      94   ...     96
# 5                 NaN            NaN    NaN    NaN     NaN  ...     NaN
#
# 0      NaN             NaN                                          NaN  \
# 1  Richest          Source   Total Population, one year before primary
# 2      75       DHS 2015                                     6,170,913
# 3      98     DHS 2017-18                                      156,833
# 4      99    MICS 2012-13                                    4,040,275
# 5      NaN             NaN                                          NaN
#
# 0        NaN        NaN           NaN           NaN     NaN     NaN
# 1        NaN        NaN           NaN           NaN     NaN     NaN
# 2  3160379.0  3010534.0  1.606042e+06  4.564871e+06  26.026  73.974
# 3    81809.0    75024.0  9.741211e+04  5.942089e+04  62.112  37.888
# 4  2060745.0  1979530.0  2.979016e+06  1.061259e+06  73.733  26.267
# 5        NaN        NaN           NaN           NaN  87.916  12.084
#
# [5 rows x 25 columns]

# %%
'''
still another first (notna) row as header and 
we had to do the same as we did for the unamed row to 
have a more presentable dataset

'''

school_data.columns = school_data.iloc[0]
school_data = school_data.iloc[1:,].reindex()
school_data.head()
# Out:
# 1 ISO_Code      Country Region Sub-region Least developed countries (LDC)  \
# 2      AFG  Afghanistan     SA        NaN                             LDC
# 3      ALB      Albania    ECA       EECA                             NaN
# 4      DZA      Algeria   MENA        NaN                             NaN
# 5      AND      Andorra    ECA         WE                             NaN
# 6      AGO       Angola    SSA        ESA                             LDC
#
# 1 Africa sub-regions Africa region Total  Male Female  ... Fourth Richest  \
# 2                NaN           NaN   54    67     40   ...    60      75
# 3                NaN           NaN   92    91     93   ...    92      98
# 4    Northern Africa           All   94    93     94   ...    96      99
# 5                NaN           NaN   NaN   NaN    NaN  ...    NaN     NaN
# 6    Southern Africa           All   51    53     49   ...    68      82
#
# 1          Source  Total Population, one year before primary         NaN  \
# 2      DHS 2015                                    6,170,913   3160379.0
# 3    DHS 2017-18                                     156,833     81809.0
# 4   MICS 2012-13                                   4,040,275   2060745.0
# 5             NaN                                         NaN        NaN
# 6    DHS 2015-16                                   5,482,624   2722689.0
#
# 1        NaN           NaN           NaN     NaN     NaN
# 2  3010534.0  1.606042e+06  4.564871e+06  26.026  73.974
# 3    75024.0  9.741211e+04  5.942089e+04  62.112  37.888
# 4  1979530.0  2.979016e+06  1.061259e+06  73.733  26.267
# 5        NaN           NaN           NaN  87.916  12.084
# 6  2759935.0  3.663763e+06  1.818861e+06  66.825  33.175
#
# [5 rows x 25 columns]

# %%
# Details about the dataset 

school_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 2 to 226
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ISO_Code                                     203 non-null    object
#  1   Country                                      222 non-null    object
#  2   Region                                       189 non-null    object
#  3   Sub-region                                   100 non-null    object
#  4   Least developed countries (LDC)              41 non-null     object
#  5   Africa sub-regions                           59 non-null     object
#  6   Africa region                                55 non-null     object
#  7   Total                                        118 non-null    object
#  8   Male                                         99 non-null     object
#  9   Female                                       99 non-null     object
#  10  Urban                                        97 non-null     object
#  11  Rural                                        97 non-null     object
#  12  Poorest                                      96 non-null     object
#  13  Second                                       95 non-null     object
#  14  Middle                                       95 non-null     object
#  15  Fourth                                       95 non-null     object
#  16  Richest                                      95 non-null     object
#  17  Source                                       99 non-null     object
#  18   Total Population, one year before primary   191 non-null    object
#  19  nan                                          191 non-null    float64
#  20  nan                                          191 non-null    float64
#  21  nan                                          191 non-null    float64
#  22  nan                                          191 non-null    float64
#  23  nan                                          202 non-null    float64
#  24  nan                                          202 non-null    float64
# dtypes: float64(6), object(19)
# memory usage: 44.1+ KB

# %%
school_data
# Out:
# 1   ISO_Code                            Country Region Sub-region  \
# 2        AFG                        Afghanistan     SA        NaN
# 3        ALB                            Albania    ECA       EECA
# 4        DZA                            Algeria   MENA        NaN
# 5        AND                            Andorra    ECA         WE
# 6        AGO                             Angola    SSA        ESA
# ..       ...                                ...    ...        ...
# 222      NaN  African sub-region - North Africa    NaN        NaN
# 223      NaN  African sub-region - South Africa    NaN        NaN
# 224      NaN   African sub-region - West Africa    NaN        NaN
# 225      NaN                Africa region - All    NaN        NaN
# 226      NaN                              World    NaN        NaN
#
# 1   Least developed countries (LDC) Africa sub-regions Africa region Total  \
# 2                               LDC                NaN           NaN   54
# 3                               NaN                NaN           NaN   92
# 4                               NaN    Northern Africa           All   94
# 5                               NaN                NaN           NaN   NaN
# 6                               LDC    Southern Africa           All   51
# ..                              ...                ...           ...   ...
# 222                             NaN    Northern Africa           NaN   91
# 223                             NaN    Southern Africa           NaN   67
# 224                             NaN     Western Africa           NaN   65
# 225                             NaN                NaN           All   66
# 226                             NaN                NaN           NaN   82
#
# 1    Male Female  ... Fourth Richest          Source  \
# 2     67     40   ...    60      75       DHS 2015
# 3     91     93   ...    92      98     DHS 2017-18
# 4     93     94   ...    96      99    MICS 2012-13
# 5     NaN    NaN  ...    NaN     NaN             NaN
# 6     53     49   ...    68      82     DHS 2015-16
# ..    ...    ...  ...    ...     ...             ...
# 222   NaN    NaN  ...    NaN     NaN             NaN
# 223   NaN    NaN  ...    NaN     NaN             NaN
# 224   NaN    NaN  ...    NaN     NaN             NaN
# 225   NaN    NaN  ...    NaN     NaN             NaN
# 226   NaN    NaN  ...    NaN     NaN             NaN
#
# 1    Total Population, one year before primary         NaN        NaN  \
# 2                                    6,170,913   3160379.0  3010534.0
# 3                                      156,833     81809.0    75024.0
# 4                                    4,040,275   2060745.0  1979530.0
# 5                                           NaN        NaN        NaN
# 6                                    5,482,624   2722689.0  2759935.0
# ..                                          ...        ...        ...
# 222                                         NaN        NaN        NaN
# 223                                         NaN        NaN        NaN
# 224                                         NaN        NaN        NaN
# 225                                         NaN        NaN        NaN
# 226                                         NaN        NaN        NaN
#
# 1             NaN           NaN     NaN     NaN
# 2    1.606042e+06  4.564871e+06  26.026  73.974
# 3    9.741211e+04  5.942089e+04  62.112  37.888
# 4    2.979016e+06  1.061259e+06  73.733  26.267
# 5             NaN           NaN  87.916  12.084
# 6    3.663763e+06  1.818861e+06  66.825  33.175
# ..            ...           ...     ...     ...
# 222           NaN           NaN     NaN     NaN
# 223           NaN           NaN     NaN     NaN
# 224           NaN           NaN     NaN     NaN
# 225           NaN           NaN     NaN     NaN
# 226           NaN           NaN     NaN     NaN
#
# [225 rows x 25 columns]

# %%
#Renam Re

school_data.rename(
    columns={"Least developed Countries": "LDC", 
             "Africa sub-regions": "Africa-sub-regions", 
             "Africa region": "Africa-region",
             "Total Population, one year before primary":"Total-Population"},
    inplace=True,
)

school_data

# %%
ISO_Code                                     
 1   Country                                      
   
 3   Sub-region                                   
 4   Least developed countries (LDC)              
 5   Africa sub-regions                           
 6   Africa region                               
 7   Total                                        
 8   Male                                       
 9   Female                                       
 10  Urban                                        
 11  Rural                                        
 12  Poorest                                      
 13  Second                                       
 14  Middle                                      
 15  Fourth                                       
 16  Richest                                      
 17  Source                                       
 18   Total Population, one year before primary   
 19  nan                                          
 20  nan                                          
 21  nan                                          
 22  nan                                          
 23  nan                                         
 24  nan

# %%
school_data['Nations'] = school_data.Least developed countries (LDC).combine_first(school_data.Total).
combine_first(chool_data.Male).combine_first(school_data.Female).combine_first(school_data.Urban).
combine_first(school_data.Rural)
# Out:
#   File "<ipython-input-21-e735057b4883>", line 1
#     school_data['Nations'] = school_data.Least developed countries (LDC).combine_first(school_data.Total).
#                                                ^
# SyntaxError: invalid syntax
